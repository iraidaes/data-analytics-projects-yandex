# %% [markdown]
# <span class="badge badge-info">ПРОГНОЗЫ И ПРЕДСКАЗАНИЯ</span>
# # Прогноз оттока клиентов из сети фитнес-центров «Культурист-датасаентист»

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# **Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных**. Распространённая проблема фитнес-клубов и других сервисов — **`отток клиентов`**. Как понять, что пользователь больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо. Индикаторы оттока зависят от специфики отрасли. Когда пользователь
# редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас. Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся. Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество анкет пользователей.
#
# **Цели проекта:** провести анализ и подготовить план действий по удержанию клиентов. А именно:
#  - научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
#  - сформировать типичные портреты пользователей: выделить несколько наиболее ярких групп и
#  - охарактеризовать их основные свойства;
#  - проанализировать основные признаки, наиболее сильно влияющие на отток;
#  - сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#      - выделить целевые группы клиентов;
#      - предложить меры по снижению оттока;
#      - определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# **Таблица `gym_churn` (данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц)**
# - 'churn' - факт оттока в текущем месяце (целевая переменная);
#
# Данные клиента за предыдущий до проверки факта оттока месяц:
#  - 'gender' — пол;
#  - 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
#  - 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#  - 'Promo_friends' — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#  - 'Phone' — наличие контактного телефона;
#  - 'Age' — возраст;
#  - 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#  - 'Contract_period' — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год);
#  - 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
#  - 'Group_visits' — факт посещения групповых занятий;
#  - 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
#  - 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
#  - 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон.

# %% [markdown]
# ## Инструкция по выполнению проекта

# %% [markdown]
# ### Шаг 1. Загрузка данных и подготовка к анализу

# %% [markdown]
#  - 1.1. Импорт библиотек и загрузка данных.
#  - 1.2. Осмотр данных.
#  - 1.3. Выводы о данных.

# %% [markdown]
# ### Шаг 2. Разведочный анализ данных (EDA)

# %% [markdown]
#  - 2.1. Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());
#  - 2.2. Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());
#  - 2.3. Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
#  - 2.4. Постройте матрицу корреляций и отобразите её.

# %% [markdown]
# ### Шаг 3. Построение модели прогнозирования оттока клиентов

# %% [markdown]
# Постройте модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
#  - 3.1. Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
#  - 3.2. Обучите модель на train-выборке двумя способами: логистической регрессией, случайным лесом.
#  - 3.3. Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#  - 3.4. Оценка важности признаков.

# %% [markdown]
# ### Шаг 4. Кластеризация клиентов

# %% [markdown]
#  - 4.1. Стандартизируйте данные.
#  - 4.2. Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.
#  - 4.3. Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).
#  - 4.4. Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
#  - 4.5. Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?
#  - 4.6. Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %% [markdown]
# ### Шаг 5. Выводы и рекомендации по работе с клиентами

# %% [markdown]
# ---

# %% [markdown]
# ## Шаг 1. Загрузка данных и подготовка к анализу

# %% [markdown]
# ### 1.1. Импорт библиотек и загрузка данных.

# %%
# Необходимые библиотеки для исследования.
import pandas as pd                                         # для анализа данных
import numpy as np                                          # для математических вычислений
import math as mth                                          # для математических вычислений

import seaborn as sns                                       # для визуализации данных
import matplotlib.pyplot as plt                             # для визуализации
import plotly.express as px                                 # для визуализации
from plotly import graph_objects as go                      # для визуализации
# %matplotlib inline

import datetime as dt                                       # для преобразования к типу данных 'дата'
import requests                                             # для HTTP запросов
import re                                                   # для работы с регулярными выражениями

import scipy.stats as stats
from scipy import stats as st                               # для высокоуровневых математических вычислений 

# Машинное обучение в Python.
from sklearn.preprocessing import StandardScaler                                    # для стандартизации данных
from sklearn.model_selection import train_test_split                                # разделение на обучающую и тестовую выборки
from sklearn.linear_model import LogisticRegression                                 # логистическая регрессия
from sklearn.metrics import roc_auc_score                                           # метрики качества
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score # метрики качества
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score       # метрики качества
from sklearn.cluster import KMeans                                                  # K-Means кластеризация
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram, linkage                             # кластеризация
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier              # дерево принятия решений 
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor       # случайный лес и градиентный бустинг
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier     # случайный лес и градиентный бустинг

import warnings                                             # для предупреждений в программе 
warnings.filterwarnings('ignore')                           # фильтр предупреждений

# %%
# Загрузка данных.
gym_churn = pd.read_csv('gym_churn.csv')            # данные на месяц до оттока и факт оттока на определённый месяц

# %%
# С помощью pd.option настроим вывод так чтобы
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None              # текст в ячейке отражался полностью вне зависимости от длины;
pd.options.display.float_format = '{:.2f}'.format   # все числа отражались с двумя знаками после запятой.

# %%
# Установка эстетических параметров графиков.
sns.set(context='notebook', style='whitegrid', palette='Set2_r', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %% [markdown]
# ### 1.2. Осмотр данных.

# %% [markdown]
# Посмотрим на 10 случайно выбранных записей из таблицы, для этого будем использовать функцию sample(). Параметр random_state=123 фиксирует "случайность", то есть на любом компьютере метод sample() будет работать одинаково.

# %%
gym_churn.sample(10, random_state=123) # получение 10 случайно выбранных записей из таблицы gym_churn
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 1203       0              1        1              0      1               12
# 2827       1              1        1              0      1               12
# 2325       1              1        1              1      0                6
# 3916       1              1        0              1      1                1
# 3821       0              1        0              0      1                1
# 2093       0              1        0              0      1                1
# 861        0              0        0              0      0                1
# 3339       0              1        0              0      1                1
# 736        1              1        1              1      1                1
# 3848       1              1        1              1      1               12
#
#       Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# ...

# %%
gym_churn.columns # получаем перечень названий столбцов таблицы gym_churn
# Out:
# Index(['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone',
#        'Contract_period', 'Group_visits', 'Age',
#        'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime',
#        'Avg_class_frequency_total', 'Avg_class_frequency_current_month',
#        'Churn'],
#       dtype='object')

# %%
gym_churn.columns = gym_churn.columns.str.lower() # приведём столбцы к нижнему регистру
gym_churn.columns.tolist() # проверка результатов
# Out:
# ['gender',
#  'near_location',
#  'partner',
#  'promo_friends',
#  'phone',
#  'contract_period',
#  'group_visits',
#  'age',
#  'avg_additional_charges_total',
#  'month_to_end_contract',
#  'lifetime',
#  'avg_class_frequency_total',
#  'avg_class_frequency_current_month',
#  'churn']

# %%
# Поменяем логику столбцов на более удобную.
gym_churn = gym_churn[['churn', 
                       'gender',
                       'near_location',
                       'partner',
                       'promo_friends',
                       'phone',
                       'group_visits',
                       'age',
                       'lifetime',
                       'contract_period',
                       'month_to_end_contract',
                       'avg_class_frequency_total',
                       'avg_class_frequency_current_month',
                       'avg_additional_charges_total']]

# %%
gym_churn.head() # получение первых 5 строк таблицы gym_churn
# Out:
#    churn  gender  near_location  partner  promo_friends  phone  group_visits  \
# 0      0       1              1        1              1      0             1
# 1      0       0              1        0              0      1             1
# 2      0       0              1        1              0      1             0
# 3      0       0              1        1              1      1             1
# 4      0       1              1        1              1      1             0
#
#    age  lifetime  contract_period  month_to_end_contract  \
# 0   29         3                6                   5.00
# 1   31         7               12                  12.00
# 2   28         2                1                   1.00
# 3   33         2               12                  12.00
# 4   26         3                1                   1.00
#
#    avg_class_frequency_total  avg_class_frequency_current_month  \
# 0                       0.02                               0.00
# ...

# %%
gym_churn['month_to_end_contract'] = gym_churn['month_to_end_contract'].astype('int') # замена типа данных

# %%
gym_churn.describe().T # выведем статистику о датасете методом describe()
# Out:
#                                     count   mean   std   min   25%    50%  \
# churn                             4000.00   0.27  0.44  0.00  0.00   0.00
# gender                            4000.00   0.51  0.50  0.00  0.00   1.00
# near_location                     4000.00   0.85  0.36  0.00  1.00   1.00
# partner                           4000.00   0.49  0.50  0.00  0.00   0.00
# promo_friends                     4000.00   0.31  0.46  0.00  0.00   0.00
# phone                             4000.00   0.90  0.30  0.00  1.00   1.00
# group_visits                      4000.00   0.41  0.49  0.00  0.00   0.00
# age                               4000.00  29.18  3.26 18.00 27.00  29.00
# lifetime                          4000.00   3.72  3.75  0.00  1.00   3.00
# contract_period                   4000.00   4.68  4.55  1.00  1.00   1.00
# month_to_end_contract             4000.00   4.32  4.19  1.00  1.00   1.00
# avg_class_frequency_total         4000.00   1.88  0.97  0.00  1.18   1.83
# ...

# %%
print("Количество пропущенных значений: {} строк".format(gym_churn.isnull().sum().sum())) # количество пропущенных значений
print("Количество дубликатов: {} строк".format(gym_churn.duplicated().sum()))             # количество дубликатов
print("Доля дубликатов от общего количества записей: {:.2%}".format((gym_churn.duplicated().sum() / len(gym_churn))))
# Out:
# Количество пропущенных значений: 0 строк
# Количество дубликатов: 0 строк
# Доля дубликатов от общего количества записей: 0.00%

# %%
print("Размер датасета:", gym_churn.shape) # получение размера датасета
# Out:
# Размер датасета: (4000, 14)

# %%
gym_churn.info() # получение общей информации о данных в таблице gym_churn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   churn                              4000 non-null   int64
#  1   gender                             4000 non-null   int64
#  2   near_location                      4000 non-null   int64
#  3   partner                            4000 non-null   int64
#  4   promo_friends                      4000 non-null   int64
#  5   phone                              4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   lifetime                           4000 non-null   int64
#  9   contract_period                    4000 non-null   int64
#  10  month_to_end_contract              4000 non-null   int32
# ...

# %% [markdown]
# ### 1.3. Выводы о данных.

# %% [markdown]
# Всего в таблице 4000 строк (наблюдений) и 14 столбца, встречаются следующие типы данных: int64 (целые числа) и float64 (вещественные числа).
#
# На этапе осмотра данных аномалий в значениях, пропусков или дубликатов не обнаружили. Привели столбцы к нижнему регистру и поменяли логику столбцов на более удобную для дальнейшей работы. В столбце 'month_to_end_contract' перевели значения с плавающей точкой в целое число.
#
# Теперь данные годятся для анализа.

# %% [markdown]
# ## Шаг 2. Разведочный анализ данных (англ. exploratory data analysis, EDA)

# %% [markdown]
# ### 2.1. Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());

# %% [markdown]
# Посмотрим на технические параметры загруженных данных. Для этого вызовем метод describe(), для удобства отображения мы транспонируем результат: меняем местами столбцы и строки.
#
# Обратим внимание на общие статистики показателей в данных:
#  - **count** - количество значений, которые не являются пропущенными (NaN);
#  - **mean, std** - среднее и разброс данных в соответствующем поле;
#  - **остальные статистики** - минимальное и максимальное значения, и квантили.

# %%
gym_churn.describe().T
# Out:
#                                     count   mean   std   min   25%    50%  \
# churn                             4000.00   0.27  0.44  0.00  0.00   0.00
# gender                            4000.00   0.51  0.50  0.00  0.00   1.00
# near_location                     4000.00   0.85  0.36  0.00  1.00   1.00
# partner                           4000.00   0.49  0.50  0.00  0.00   0.00
# promo_friends                     4000.00   0.31  0.46  0.00  0.00   0.00
# phone                             4000.00   0.90  0.30  0.00  1.00   1.00
# group_visits                      4000.00   0.41  0.49  0.00  0.00   0.00
# age                               4000.00  29.18  3.26 18.00 27.00  29.00
# lifetime                          4000.00   3.72  3.75  0.00  1.00   3.00
# contract_period                   4000.00   4.68  4.55  1.00  1.00   1.00
# month_to_end_contract             4000.00   4.32  4.19  1.00  1.00   1.00
# avg_class_frequency_total         4000.00   1.88  0.97  0.00  1.18   1.83
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Судя по полученным результатам, из столбцов можем извлечь следующую информацию о данных:
#
#  - Доля оттока 27%. У столбца 'churn' среднее 0,27, значит, в нашей выборке только 27% клиентов ушли из сети фитнес-центров.
#  - Почти одинаковое распределение по полу (gender).
#  - 85% клиентов проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 49% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 31% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Наличие контактного телефона примерно 90% клиентов (phone).
#  - 41% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 29 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 3,7 месяца (lifetime).
#  - Средняя длительность текущего действующего абонемента 4,6 месяца (contract_period).
#  - Средний срок до окончания текущего действующего абонемента 4,3 месяца (month_to_end_contract).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента 1,8 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц 1,7 раз (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 147 (avg_additional_charges_total).
#
# В датасете нет отсутствующих признаков.

# %% [markdown]
# ### 2.2. Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());

# %%
# Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался.
# Где, 0 = оставшиеся клиенты; 1 = отток.
gym_churn_mean = gym_churn.groupby('churn').agg('mean').T
gym_churn_mean
# Out:
# churn                                  0      1
# gender                              0.51   0.51
# near_location                       0.87   0.77
# partner                             0.53   0.36
# promo_friends                       0.35   0.18
# phone                               0.90   0.90
# group_visits                        0.46   0.27
# age                                29.98  26.99
# lifetime                            4.71   0.99
# contract_period                     5.75   1.73
# month_to_end_contract               5.28   1.66
# avg_class_frequency_total           2.02   1.47
# avg_class_frequency_current_month   2.03   1.04
# avg_additional_charges_total      158.45 115.08

# %% [markdown]
# ### Вывод

# %% [markdown]
#  - Одинаковое распределение по полу.
#  - Клиенты проживающие или работающие в районе, где находится фитнес-центр, реже попадают в отток.
#  - Сотрудники компаний-партнеров клуба реже перестают посещать фитнес-клуб чем остальные клиенты.
#  - Клиенты пришедшие по акции «приведи друга», почти в два раза реже уходят в отток.
#  - Одинаковое наличие контактного телефона клиента в группах.
#  - Клиенты, которые уходят в отток меньше посещают групповые занятия.
#  - Клиенты, которые уходят в отток моложе возрастом, чем те, кто остается. Разница в три года.
#  - Время с момента первого обращения в фитнес-центр (в месяцах) у клиентов, которые уходят в отток, намного меньше, чем у оставшихся клиентов.
#  - Средняя длительность действующего абонемента у клиентов, которые уходят в отток, намного меньше, чем у оставшихся клиентов.
#  - Средний срок до окончания текущего действующего абонемента у тех, кто ушел в отток, меньше.
#  - Средняя частота посещений в неделю и за все время меньше у тех, кто ушел в отток.
#  - Меньше и средняя суммарная выручка от других услуг фитнес-центра у тех, кто ушел в отток.

# %% [markdown]
# ### 2.3. Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %%
# Посмотрим, как соотносятся классы для нашего набора данных.
gym_churn['churn'].value_counts()
# Out:
# 0    2939
# 1    1061
# Name: churn, dtype: int64

# %%
# Построим гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).
# Создадим два отдельных датасета с разделением по ключевому признаку 'сhurn'.
# Где 0 = оставшиеся клиенты; 1 = отток.
gym_churn_0 = gym_churn[gym_churn['churn']==0].reset_index(drop=True).drop('churn', axis=1)
gym_churn_1 = gym_churn[gym_churn['churn']==1].reset_index(drop=True).drop('churn', axis=1)

# Цикл для создания гистограмм.
for feature in gym_churn_0.columns:
    plt.figure(figsize=(5,5))
    plt.title("Распределение для признака: " + feature)
    sns.distplot(gym_churn_0[feature], bins = 10, label="Оставшиеся") #norm_hist=False, kde=False
    sns.distplot(gym_churn_1[feature], bins = 10, label="Отток", color="black")
    plt.show()

# %%
# Цикл для построения графиков для количественных признаков.
for feature in ['age', 'lifetime', 'contract_period', 'month_to_end_contract', \
               'avg_class_frequency_total', 'avg_class_frequency_current_month', 'avg_additional_charges_total']:
    plt.figure(figsize=(5,5))
    plt.title("Распределение для признака: " + feature)
    sns.boxplot(x='churn', y=gym_churn[feature], data=gym_churn)
    plt.show()

# %%
# Посмотрим на основные статистические показатели количественных признаков.
# Посчитаем среднее и медианное количество, дисперсию и стандартное отклонение для количественных признаков.
desc_stat_churn = gym_churn.pivot_table(index=['churn'],
                  values=['age', 'lifetime', 'contract_period', 'month_to_end_contract', 
                          'avg_class_frequency_total', 'avg_class_frequency_current_month', 'avg_additional_charges_total'], 
                  aggfunc={'age': [np.mean, np.median, np.std, np.var], 
                           'lifetime': [np.mean, np.median, np.std, np.var], 
                           'contract_period': [np.mean, np.median, np.std, np.var],
                           'month_to_end_contract': [np.mean, np.median, np.std, np.var],
                           'avg_class_frequency_total': [np.mean, np.median, np.std, np.var],
                           'avg_class_frequency_current_month': [np.mean, np.median, np.std, np.var],
                           'avg_additional_charges_total': [np.mean, np.median, np.std, np.var]})
desc_stat_churn.T
# Out:
# churn                                          0       1
# age                               mean     29.98   26.99
#                                   median   30.00   27.00
#                                   std       3.01    2.90
#                                   var       9.06    8.38
# avg_additional_charges_total      mean    158.45  115.08
#                                   median  149.88  103.81
#                                   std      99.80   77.70
#                                   var    9960.36 6036.73
# avg_class_frequency_current_month mean      2.03    1.04
#                                   median    2.05    0.98
#                                   std       1.02    0.77
#                                   var       1.04    0.59
# avg_class_frequency_total         mean      2.02    1.47
#                                   median    2.04    1.49
#                                   std       1.02    0.69
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Судя по графикам, видим, что **чаще уходят клиенты, которые**:
#
#  - дальше живут или работают от фитнес-центра;
#  - реже являются партнерами или сотрудниками клуба;
#  - реже приходят по программе «приведи друга»;
#  - моложе;
#  - реже посещают групповые занятия;
#  - меньше проводят времени в фитнес-центре;
#  - в основном, покупают абонемент на один месяц;
#  - реже посещают зал, от 1 до 2 раз в неделю;
#  - более экономные (тратят меньше).
#
# По основным статистическим показателям, у большинства количественных признаков стандартное отклонение не превышает среднего значения, это говорит о том, что серьезных аномалий или выбросов не наблюдаются.
#
# Однако, выделяются такие признаки как 'contract_period', 'lifetime' и 'month_to_end_contract', у которых в оттоке наблюдаются незначительные выбросы, но не критично, их присутствие не повлияет на результаты анализа, принимаю решение на данном этапе их не удалять.

# %% [markdown]
# ### 2.4. Постройте матрицу корреляций и отобразите её.

# %% [markdown]
# Для выявления коррелирующих признаков в датафрейме построим матрицу корреляции с помощью метода .corr()

# %%
# Построим матрицу корреляций и отобразим её.
plt.figure(figsize=(15,10))
sns.heatmap(data=gym_churn.corr(), annot=True, square=True, cmap='Set2_r', alpha=.5, fmt='.2f')
plt.title('«Корреляционная матрица»', fontsize=16)
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# **Явной взаимозависимости факта оттока ('churn' целевая переменная) с признаками не обнаружено.** Однако, есть небольшая взаимозависимость фактора оттока с признаком 'lifetime', время с момента первого обращения в фитнес-центр, corr = -0, 44, то есть чем меньше прошло времени с момента первого обращения в фитнес-центр, тем выше вероятность того, что клиент попадёт в отток.
#
# Также, есть признаки, которые сильно коррелируют между собой, это:
#  - 'contract_period' и 'month_to_end_contract', corr = 0,97;
#  - 'аvg_class_frequency_total' и 'аvg_class_frequency_current_month', corr = 0,95.
#
# Наблюдается проблема частичной `мультиколлинеарности`. Мультиколлинеарность возникает, когда есть группа линейно зависимых признаков — взаимозависимых или очень сильно скоррелированных (часто коэффициент корреляции больше 0,8). Можно будет убрать один из пары более коррелирующих признаков.

# %%
# Чтобы избавиться от мультиколлинеарности, удалим из датафрейма один из пар:
gym_churn.drop('month_to_end_contract', axis = 1, inplace = True)
gym_churn.shape
# Out:
# (4000, 13)

# %% [markdown]
# Можно сравнить качество моделей до и после удаления признаков и выбрать оптимальный вариант.

# %% [markdown]
# ## Шаг 3. Построение модели прогнозирования оттока клиентов

# %% [markdown]
# Для построения модели прогнозирования оттока клиентов будем использовать следующие модели **`бинарной классификации`**:
#
#  - логистическая регрессия - Logistic Regression
#  - модель случайного леса - Random Forest Classifier
#  - градиентный бустинг - Gradient Boosting (дополнительный)
#
# Для начала, вызовем функцию train_test_split() из модуля model_selection библиотеки sklearn.

# %% [markdown]
# ### 3.1. Разбейте данные на обучающую и валидационную выборку функцией train_test_split().

# %%
# Разделим данные на признаки (матрица X) и целевую переменную (y)
X = gym_churn.drop('churn', axis = 1)
y = gym_churn['churn']

# Разделим данные на обучающую 80% 'train' и валидационную 20% 'test' выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### 3.2. Обучите модель на train-выборке двумя способами: логистической регрессией, случайным лесом.

# %% [markdown]
# **Логистическая регрессия - Logistic Regression**

# %%
# Обучим StandartScaler на обучающей выборке.
scaler = StandardScaler()
scaler.fit(X_train)

# Преобразуем обучающий и валидационные наборы данных.
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# Зададим алгоритм для модели логистической регрессии.
lr_model = LogisticRegression(random_state=0)

# Обучим модель.
lr_model.fit(X_train_st, y_train)

# Воспользуемся уже обученной моделью, чтобы сделать прогнозы.
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# **Случайный лес - Random Forest Classifier**

# %%
# Зададим алгоритм для новой модели на основе алгоритма случайного леса.
# Кол-во деревьев 100, параметр bootstrap True, глубина дерева 12.
rf_model = RandomForestClassifier(n_estimators = 100, bootstrap = True, max_depth=12, random_state = 0) 

# Обучим модель случайного леса.
rf_model.fit(X_train_st, y_train)

# Воспользуемся уже обученной моделью, чтобы сделать прогнозы.
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# **Градиентный бустинг - Gradient Boosting** (дополнительный)

# %%
# Сделаем все то же самое для алгоритма градиентного бустинга.
gb_model = GradientBoostingClassifier(n_estimators = 100, random_state = 0)
gb_model.fit(X_train_st, y_train)
gb_predictions = gb_model.predict(X_test_st)
gb_probabilities = gb_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# ### 3.3. Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?

# %% [markdown]
# Для оценки качества полученных прогнозов и выбора лучшей модели сравним следующие метрики:
#
#  - **Accuracy**: доля правильных ответов. Чем ближе к единице, тем лучше.
#  - **Precision**: точность модели. Чем ближе к единице, тем лучше.
#  - **Recall**: полнота модели. Чем ближе к единице, тем лучше.
#  - **F1-мера**: так как precision и recall направлены на избежание противоположных рисков, нужна сводная метрика, учитывающая баланс между метриками. Чем ближе к единице, тем лучше.
#  - **ROC_AUC**: Area Under Curve, площадь под кривой ошибок. Подходит даже для несбалансированных классов. Чем ближе к единице, тем лучше.

# %%
# Определим функцию, которая будет выводить наши метрики.
def print_all_metrics(y_true, y_pred, y_proba, title = "Метрики классификации"):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    print('\tROC_AUC: {:.2f}'.format(roc_auc_score(y_true, y_proba))) 

# Выведем все метрики для модели логистической регрессии.
print_all_metrics(y_test, lr_predictions, lr_probabilities, title='Метрики для модели логистической регрессии:')

# Выведем все метрики для модели случайного леса.
print_all_metrics(y_test, rf_predictions, rf_probabilities, title='Метрики для модели случайного леса:')

# Выведем все метрики градиентного бустинга.
print_all_metrics(y_test, gb_predictions, gb_probabilities, title='Метрики для модели градиентного бустинга:')
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.83
# 	F1: 0.84
# 	ROC_AUC: 0.97
# Метрики для модели случайного леса:
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.84
# 	F1: 0.84
# 	ROC_AUC: 0.97
# Метрики для модели градиентного бустинга:
# 	Accuracy: 0.93
# 	Precision: 0.87
# 	Recall: 0.83
# 	F1: 0.85
# 	ROC_AUC: 0.98

# %% [markdown]
# ### Вывод

# %% [markdown]
# Так как, модель логистической регрессии и случайного леса показывают себя почти одинокого хорошо, было принято решение добавить модель градиентного бустинга. По результатам, модель которая показывает себя лучше всех на основании метрик, это **градиентный бустинг**. На втором месте модель **случайного леса**.

# %% [markdown]
# ### 3.4. Оценка важности признаков

# %%
# Создадим датафрейм с именами признаков и их важностью и выведем его по убыванию важности.
feature_importance_data = pd.DataFrame(data={'feature': X.columns, 'importance': gb_model.feature_importances_})
feature_importance_data.sort_values('importance', ascending=False)
# Out:
#                               feature  importance
# 7                            lifetime        0.47
# 10  avg_class_frequency_current_month        0.17
# 8                     contract_period        0.13
# 9           avg_class_frequency_total        0.10
# 6                                 age        0.09
# 11       avg_additional_charges_total        0.03
# 5                        group_visits        0.01
# 3                       promo_friends        0.00
# 1                       near_location        0.00
# 0                              gender        0.00
# 4                               phone        0.00
# 2                             partner        0.00

# %%
# Построим график swarmplot.
plt.figure(figsize=(10,10))
sns.swarmplot(x="importance", y="feature", data=feature_importance_data, hue="feature", size=18, palette="Set2_r")
plt.title('«Оценка важности признаков»', fontsize=16)
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Видим три важных признака которые особа влияют на прогноз модели, это:
#  - `'lifetime'` - время с момента первого обращения в фитнес-центр (в месяцах)
#  - `'avg_class_frequency_current_month'` - средняя частота посещений в неделю за предыдущий месяц
#  - `'contract_period'` - длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)

# %% [markdown]
# ## Шаг 4. Кластеризация клиентов

# %% [markdown]
# Для сегментации клиентов, которые наиболее склонны к оттоку, необходимо провести **кластеризацию**. Кластеризация поможет их выделить и предложить каждому сегменту подходящий вариант продукта и точную коммуникацию. Для этого необходимо рассчитать матрицу расстояний между всеми признаками с помощью класса linkage.

# %% [markdown]
# ### 4.1. Стандартизируйте данные.

# %%
# Создим объект класса Scaler.
scaler = StandardScaler()

# Обучим нормализатор и преобразуем набор данных. Без'churn' целевой переменной.
X_st = scaler.fit_transform(X)

# %% [markdown]
# ### 4.2. Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.

# %%
# Расчитаем матрицу расстояний с помощью метода linkage.
linked = linkage(X_st, method = 'ward')

# Построим график дендрограмма.
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top', show_leaf_counts=False, truncate_mode='lastp', p=30, leaf_rotation=90, leaf_font_size=16)
plt.title("«Дендрограмма клиентов сети фитнес-центров»", fontsize=16)
plt.xlabel("Размер кластера")
plt.ylabel("Расстояние")
plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Предложенное оптимальное `число кластеров 5`, пять разных цветов на графике.

# %% [markdown]
# ### 4.3. Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).

# %% [markdown]
# В библиотеке Scikit-Learn имеется множество алгоритмов кластеризации, но, вероятно, наиболее простой для понимания — **алгоритм кластеризации методом k-средних (k-means clustering)**, реализованный в классе sklearn.cluster.KMeans.
#
# Алгоритм K-Means группирует пошагово все объекты. Вот принцип его работы:
#  - Есть K кластеров. Алгоритм пошагово подбирает их центры и относит объекты к тому кластеру, чей центр ближе.
#  - Центры корректируются (меняют своё положение) до тех пор, пока это позволяет минимизировать среднее расстояние от объектов каждого кластера до его центра.
#  - Когда расстояние от объектов до центра перестаёт снижаться или сокращается несущественно, алгоритм останавливается и фиксирует разбиение, считая его оптимальным.
#
# Разобравшись в устройстве алгоритма, запустим его в JupyterNotebook.
#
# `Источник`: яндекс.практикум; «Python для сложных задач: наука о данных и машинное обучение» — СПб.: Питер, 2018. — 576 с.: ил. — (Серия «Бестселлеры O’Reilly»). ISBN 978-5-496-03068-7

# %%
# задаём модель k_means с числом кластеров n=5
k_means = KMeans(n_clusters = 5, random_state=1)

# прогнозируем кластеры для наблюдений (алгоритм присваивает им номера от 0 до 4)
labels = k_means.fit_predict(X_st)

# присваиваю каждому наблюдению в датафрейме соответствующее значение кластера 
gym_churn['cluster_km'] = labels

# %% [markdown]
# ### Вывод

# %% [markdown]
# Кластеризация по алгоритму K-Means выполнена.

# %% [markdown]
# ### 4.4. Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %%
# Выводим статистику по средним значениям признаков по кластеру.
cluster_means = gym_churn.groupby(['cluster_km']).mean().T
cluster_means
# Out:
# cluster_km                             0      1      2      3      4
# churn                               0.04   0.10   0.50   0.27   0.42
# gender                              0.57   0.48   0.49   0.52   0.50
# near_location                       0.97   0.99   1.00   0.86   0.00
# partner                             0.31   0.95   0.24   0.47   0.49
# promo_friends                       0.10   0.88   0.10   0.31   0.08
# phone                               1.00   1.00   1.00   0.00   1.00
# group_visits                        0.48   0.54   0.33   0.43   0.23
# age                                30.29  29.63  28.22  29.28  28.57
# lifetime                            5.01   4.45   2.44   3.92   2.91
# contract_period                     5.14   7.83   2.48   4.76   2.86
# avg_class_frequency_total           2.88   1.84   1.26   1.85   1.67
# avg_class_frequency_current_month   2.88   1.80   1.03   1.72   1.50
# avg_additional_charges_total      166.18 154.79 131.34 144.24 136.38

# %% [markdown]
# ### Вывод

# %% [markdown]
# **Кластер 0**
#  - Доля оттока 4% (самый низкий).
#  - 97% клиентов проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 31% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 10% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Наличие контактного телефона примерно 100% клиентов (phone).
#  - 49% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 30 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 5 месяцев (lifetime).
#  - Средняя длительность текущего действующего абонемента 5 месяца (contract_period).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента почти 3 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц почти 3 раза (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 166 (avg_additional_charges_total).
#
# **Кластер 1**
#  - Доля оттока 10%.
#  - 99% клиентов проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 95% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 88% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Наличие контактного телефона примерно 100% клиентов (phone).
#  - 54% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 29 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 4 месяца (lifetime).
#  - Средняя длительность текущего действующего абонемента 7 месяца (contract_period).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента почти 2 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц почти 1 раза (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 154 (avg_additional_charges_total).
#
# **Кластер 2**
#  - Доля оттока 50% (самый высокий).
#  - 100% клиентов проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 24% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 10% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Наличие контактного телефона примерно 100% клиентов (phone).
#  - 33% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 28 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 2 месяцев (lifetime).
#  - Средняя длительность текущего действующего абонемента 2 месяца (contract_period).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента почти 1 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц почти 1 раза (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 131 (avg_additional_charges_total).
#
# **Кластер 3**
#  - Доля оттока 27%.
#  - 86% клиентов проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 47% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 31% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Не имеют наличие контактного телефона (phone).
#  - 43% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 29 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 4 месяцев (lifetime).
#  - Средняя длительность текущего действующего абонемента 4 месяца (contract_period).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента почти 2 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц почти 1 раза (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 144 (avg_additional_charges_total).
#
# **Кластер 4**
#  - Доля оттока 42%.
#  - Клиенты не проживают или работают в районе, где находится фитнес-центр (near_location).
#  - 49% клиентов являются сотрудниками компании-партнёра клуба (partner).
#  - 7% клиентов пришли по программе «приведи друга» (promo_friends).
#  - Наличие контактного телефона примерно 100% клиентов (phone).
#  - 23% клиентов посещают групповые занятия (group_visits).
#  - Средний возраст клиентов 28 лет (age).
#  - Среднее время с момента первого обращения в фитнес-центр 3 месяца (lifetime).
#  - Средняя длительность текущего действующего абонемента 3 месяца (contract_period).
#  - Средняя частота посещений в неделю за все время с начала действия абонемента почти 1 раз (avg_class_frequency_total).
#  - Средняя частота посещений в неделю за предыдущий месяц почти 1 раза (avg_class_frequency_current_month).
#  - Средняя суммарная выручка от других услуг фитнес-центра 136 (avg_additional_charges_total).

# %% [markdown]
# ### 4.5. Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
# Список с бинарными признаками.
list_1 = ['churn','gender', 'near_location', 'partner', 
       'promo_friends', 'phone', 'group_visits','contract_period'] 

# Цикл для построения графиков для бинарных признаков.
fig , ax = plt.subplots(4,2,figsize=(10,15))

for axis,column in zip(ax.flat,list_1):
    sns.countplot(x=gym_churn[column], hue=gym_churn['cluster_km'], palette='Set2_r', ax=axis)

# %%
# Список с количественными признаками. 
list_2 = ['age', 'lifetime', 'avg_class_frequency_current_month', 'avg_additional_charges_total'] 

# Цикл для построения графиков для количественных признаков.
fig , ax = plt.subplots(2,2,figsize=(15,10))

for axis,column in zip(ax.flat,list_2):
    sns.boxplot(x=gym_churn['cluster_km'], y=gym_churn[column], palette='Set2_r', ax=axis, showfliers=False)

# %% [markdown]
# ### Вывод

# %% [markdown]
# По графикам видим, что **чаще всего уходят клиенты второго кластера**, которые:
#
#  - проживают или работают в районе, где находится фитнес-центр;
#  - реже являются сотрудниками компании-партнёра клуба;
#  - реже приходят по программе «приведи друга»;
#  - реже посещают групповые занятия;
#  - меньше остальных проводят время в фитнес-центре;
#  - в основном, покупают абонемент на месяц;
#  - реже посещают зал, от 1 до 2 раз в неделю;
#  - более экономные (тратят меньше), чем клиенты других групп.
#
# Самые хорошие показатели у кластера 0, на них нужно ориентироваться. У них самая низкая доля оттока, тратят больше чем другие клиенты, проводят больше времени в фитнес-центре и контрактный период у них достаточно долгий.

# %% [markdown]
# ### 4.6. Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %%
# Для каждого полученного кластера посчитаем долю оттока (методом groupby()).
gym_churn_grouped = gym_churn.groupby('cluster_km').mean().reset_index()[['cluster_km', 'churn']]
gym_churn_grouped['ratio_churn'] = (gym_churn_grouped['churn'] * 100).round(2)
gym_churn_grouped[['cluster_km', 'ratio_churn']].sort_values(by='ratio_churn', ascending=False)
# Out:
#    cluster_km  ratio_churn
# 2           2        50.21
# 4           4        42.03
# 3           3        26.75
# 1           1        10.25
# 0           0         4.10

# %% [markdown]
# ### Вывод

# %% [markdown]
# Кластеры, которые склонны к оттоку, это следующие:
#
#  - кластер 2 с вероятностью 50%
#  - кластер 4 с вероятностью 42%
#  - кластер 3 с вероятностью 27%
#  - кластер 1 с вероятностью 10%, является надежным
#  - кластер 0 с вероятностью 4%, является самым надежным

# %% [markdown]
# ## Шаг 5. Выводы и рекомендации по работе с клиентами

# %% [markdown]
# **Подводя итоги, имеющиеся факты:**
#
# **По результатам разведочного анализа данных:**
#
# Получили следующую информацию о данных:
#
#  - Доля оттока составляет 27%.
#  - Почти одинаковое распределение по полу.
#  - Большинство клиентов проживают или работают в районе, где находится фитнес-центр.
#  - Почти половина клиентов являются сотрудниками компании-партнёра клуба.
#  - 31% клиентов пришли по программе «приведи друга».
#  - Наличие контактного телефона примерно 90% клиентов.
#  - 41% клиентов посещают групповые занятия.
#  - Средний возраст клиентов 29 лет.
#  - Среднее время с момента первого обращения в фитнес-центр 4 месяца.
#  - Средняя длительность текущего действующего абонемента 4 месяца.
#  - Средний срок до окончания текущего действующего абонемента 4 месяца.
#  - Средняя частота посещений в неделю за все время с начала действия абонемента 2 раза.
#  - Средняя частота посещений в неделю за предыдущий месяц 2 раза.
#  - Средняя суммарная выручка от других услуг фитнес-центра 147 д.е.
#
# Клиенты, которые чаще уходят, имеют следующие характеристики:
#
#  - живут или работают дальше от фитнес-центра;
#  - реже являются партнерами или сотрудниками клуба;
#  - реже приходят по программе «приведи друга»;
#  - они моложе;
#  - реже посещают групповые занятия;
#  - меньше проводят времени в фитнес-центре;
#  - в основном, покупают абонемент на один месяц;
#  - реже посещают зал, 1 раз в неделю;
#  - более экономные (тратят меньше на другие услуги клуба).
#
# По результатам корреляционной матрицы, явной взаимозависимости факта оттока с признаками не обнаружено. Однако, есть небольшая взаимозависимость фактора оттока с признаком 'lifetime', время с момента первого обращения в фитнес-центр, corr = -0, 44, то есть чем меньше прошло времени с момента первого обращения в фитнес-центр, тем выше вероятность того, что клиент попадёт в отток. Также, есть признаки, которые сильно коррелируют между собой, это:
#  - 'contract_period' и 'month_to_end_contract', corr = 0,97;
#  - 'аvg_class_frequency_total' и 'аvg_class_frequency_current_month', corr = 0,95.
#
# Наблюдается проблема частичной мультиколлинеарности. Чтобы избавиться от нее мы убрали один признак из пары, срок до окончания текущего действующего абонемента (в месяцах), что положительно повлияло на метрики моделей для прогнозирования оттока.
#
# **По результатам построения модели прогнозирования оттока клиентов:**
#
# При выборе модели для прогнозирования, модель логистической регрессии и случайного леса показали себя одинокого хорошо, поэтому, было принято решение добавить модель градиентного бустинга. По результатам, модель которая показала себя лучше всех на основании метрик, это градиентный бустинг. На втором месте модель случайного леса.
#
# Выявили признаки, которые наиболее влияют на прогноз оттока, это:
#  - 'lifetime' - время с момента первого обращения в фитнес-центр (в месяцах)
#  - 'avg_class_frequency_current_month' - средняя частота посещений в неделю за предыдущий месяц
#  - 'contract_period' - длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
#
#
# **По результатам кластеризации клиентов:**
#
# Кластеризация выделила оптимальное число кластеров 5.
# Кластеры, которые склонны к оттоку, это следующие:
#  - кластер 2 с вероятностью 50%
#  - кластер 4 с вероятностью 42%
#  - кластер 3 с вероятностью 27%
#  - кластер 1 с вероятностью 10%, является надежным
#  - кластер 0 с вероятностью 4%, является самым надежным
#
# Чаще уходят клиенты второго кластера:
#
# **Кластер 2**
#  - доля оттока 50% (самый высокий);
#  - проживают или работают в районе, где находится фитнес-центр;
#  - реже являются сотрудниками компании-партнёра клуба;
#  - реже приходят по программе «приведи друга»;
#  - реже посещают групповые занятия;
#  - меньше остальных проводят время в фитнес-центре;
#  - в основном, покупают абонемент на месяц;
#  - реже посещают зал, 1 раз в неделю;
#  - более экономные (тратят меньше), чем клиенты других групп.
#
# **Самые хорошие показатели у кластера 0**, на них нужно ориентироваться. У них самая низкая доля оттока, тратят больше чем другие клиенты, проводят больше времени в фитнес-центре и контрактный период у них достаточно долгий.
#
# **Кластер 0**
#  - доля оттока 4% (самый низкий);
#  - 97% клиентов проживают или работают в районе, где находится фитнес-центр (near_location);
#  - реже являются сотрудниками компании-партнёра клуба (partner);
#  - 10% клиентов пришли по программе «приведи друга» (promo_friends);
#  - наличие контактного телефона 100% клиентов (phone);
#  - половина клиентов посещают групповые занятия (group_visits);
#  - средний возраст клиентов 30 лет (age);
#  - среднее время с момента первого обращения в фитнес-центр 5 месяцев (lifetime);
#  - средняя длительность текущего действующего абонемента 5 месяца (contract_period);
#  - средняя частота посещений в неделю за все время с начала действия абонемента почти 3 раз (avg_class_frequency_total);
#  - средняя частота посещений в неделю за предыдущий месяц почти 3 раза (avg_class_frequency_current_month);
#  - средняя суммарная выручка от других услуг фитнес-центра 166 (avg_additional_charges_total).
#
# ### **`Исходя из вышеупомянутого, рекомендации по повышению качества работы с клиентами следующие:`**
#
#  - **Обратить внимание на три ключевых признака**:
#     - 'lifetime' - время с момента первого обращения в фитнес-центр (в месяцах);
#     - 'avg_class_frequency_current_month' - средняя частота посещений в неделю за предыдущий месяц;
#     - 'contract_period' - длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год).
#
#
#  - **Создать «программы», «challenges/вызовы»**, для удержания клиентов, **благодаря которым клиенты будут мотивированы заниматься спортом**, так, чтобы это вошло в привычку и стало частью ежедневной/еженедельной рутины.
#
#
#  - Самые интересные, для клиента, могут быть «challenges/вызовы», где клиент в конце челеджа получает свой приз бесплатно от фитнес-центра. За определенное время, допустим месяц, клиент должен выполнить определение количество занятий или упражнений, отмечая фитнес-инструктором у себя в карточке. Призом может быть мерч-футболка, в которой он может заниматься в зале (брендированный товар клуба, который также может продаваться для тех кто не принимает участие в них).
#
#
#  - **Улучшить коммуникацию с клиентом.** Иногда клиенты чувствуют себя дезориентированными в зале, в этих случаях coach/фитнес-инструктор зала должен обратить внимание и помочь таким клиентам. Предположим, предлагая бесплатную таблицу упражнений в соответствии с его потребностями и характеристиками тела, которую клиент должен выполнять в зале, на протяжении n-ного времени, чтобы получить желаемые результаты. Также, можно предложить персональные тренировки, как дополнительные услуги, которые не входят в абонемент, 2 раза в неделю, 1 раз в неделю, предположим. Или мотивировать заниматься групповыми занятиями, тем самым продвигая услуги клуба.
#
#
#  - **Улучшить качество услуг.**
